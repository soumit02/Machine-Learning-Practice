# %% [markdown]
# # Titanic Dataset

# %% [markdown]
# ## Import Libraries & data visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url="https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df=pd.read_csv(url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
len(df)
# Out:
# 891

# %%
df.shape
# Out:
# (891, 12)

# %%
len(df.columns)
# Out:
# 12

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# num of unique values
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# missing 2 rows for titanic_df for Embarked column
df[df['Embarked'].isnull()==True] # inside df[] have condition
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: str

# %% [markdown]
# ## Single condition checking

# %%
df['Sex']=='male' # only condition
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Sex']=='male'][['Sex','Age']]
# Out:
#       Sex   Age
# 0    male  22.0
# 4    male  35.0
# 5    male   NaN
# 6    male  54.0
# 7    male   2.0
# ..    ...   ...
# 883  male  28.0
# 884  male  25.0
# 886  male  27.0
# 889  male  26.0
# 890  male  32.0
#
# [577 rows x 2 columns]

# %%
df[df['Sex']=='male']['Sex'].value_counts()
# Out:
# Sex
# male    577
# Name: count, dtype: int64

# %% [markdown]
# ## Advanced condition checking

# %%
# the people who survived under age 15
df[(df['Age'] < 15) & (df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 78            79         1       2
# 125          126         1       3
# 165          166         1       3
# 172          173         1       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 305          306         1       1
# 340          341         1       2
# 348          349         1       3
# 381          382         1       3
# 407          408         1       2
# 435          436         1       1
# 445          446         1       1
# 446          447         1       2
# 448          449         1       3
# 469          470         1       3
# ...

# %%
df[(df['Pclass'] == 3) | (df['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# ..           ...       ...     ...                                       ...
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# ## Statistical analysis

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# percentage distribution
df['Sex'].value_counts(normalize=True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
l=[2,4,6]
avg=sum(l)/len(l)
print(avg)
# Out:
# 4.0

# %%
# Here, the mean does not represent everyone well. Here the data is skew data. The average age is 36.5, which means that the average age of men is 36.5. But the age of someone is just upper than 36.
import numpy as np
np.array([20, 22, 27, 32, 28, 90]).mean()
# Out:
# np.float64(36.5)

# %%
# Here, using the median will give you the correct age.
np.median(np.array([20, 22, 27, 32, 28, 90]))
# Out:
# np.float64(27.5)

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: str

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Indexing, Selecting & Assigning

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df['Age'] # column access
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[['Name','Age','Survived']] # multiple column access
# Out:
#                                                   Name   Age  Survived
# 0                              Braund, Mr. Owen Harris  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                             Allen, Mr. William Henry  35.0         0
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         0
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                              Behr, Mr. Karl Howell  26.0         1
# 890                                Dooley, Mr. Patrick  32.0         0
#
# [891 rows x 3 columns]

# %%
df.iloc[0:3] # iloc used for row access
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Extract the columns representing Survived, Name and Sex
df.iloc[:,[1,3,4]]
# Out:
#      Survived                                               Name     Sex
# 0           0                            Braund, Mr. Owen Harris    male
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2           1                             Heikkinen, Miss. Laina  female
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0                           Allen, Mr. William Henry    male
# ..        ...                                                ...     ...
# 886         0                              Montvila, Rev. Juozas    male
# 887         1                       Graham, Miss. Margaret Edith  female
# 888         0           Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1                              Behr, Mr. Karl Howell    male
# 890         0                                Dooley, Mr. Patrick    male
#
# [891 rows x 3 columns]

# %%
df.loc[0:3, ['Age','Survived']] # loc used for row column access
# Out:
#     Age  Survived
# 0  22.0         0
# 1  38.0         1
# 2  26.0         1
# 3  35.0         1

# %%
df.loc[3,'Ticket']
# Out:
# '113803'

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.loc[df["Age"] > 30, ["Age", "Pclass"]] # used loc with condition
# Out:
#       Age  Pclass
# 1    38.0       1
# 3    35.0       1
# 4    35.0       3
# 6    54.0       1
# 11   58.0       1
# ..    ...     ...
# 873  47.0       3
# 879  56.0       1
# 881  33.0       3
# 885  39.0       3
# 890  32.0       3
#
# [305 rows x 2 columns]

# %% [markdown]
# ## Note:
# ### df[column_name] -> col
# ### df.iloc[index] -> row
# ### df.loc[index, col_name] -> row, col (find particular data)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
# create dataframe from dictionary of lists
data = {
    "Name": ["A", "B", "C","D","E"],
    "Age": [20, 25, 30,15,16]
}
df1 = pd.DataFrame(data)
df1
# Out:
#   Name  Age
# 0    A   20
# 1    B   25
# 2    C   30
# 3    D   15
# 4    E   16

# %%
# each dict = one row
data = [
    {"Name": "A", "Age": 20},
    {"Name": "B", "Age": 25}
]
df2 = pd.DataFrame(data)
df2
# Out:
#   Name  Age
# 0    A   20
# 1    B   25

# %%
df1.loc[0,'Name'] = "Soumit"
df1
# Out:
#      Name  Age
# 0  Soumit   20
# 1       B   25
# 2       C   30
# 3       D   15
# 4       E   16

# %%
# Assign new column | Feature Generation
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df[['Name','Sex','FamilySize']].head()
# Out:
#                                                 Name     Sex  FamilySize
# 0                            Braund, Mr. Owen Harris    male           2
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female           2
# 2                             Heikkinen, Miss. Laina  female           1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female           2
# 4                           Allen, Mr. William Henry    male           1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize
# 0      0         A/5 21171   7.2500   NaN        S           2
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1
# ...

# %% [markdown]
# ## Summary Functions and Maps

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].argmax()
# Out:
# np.int64(630)

# %%
df.iloc[630]
# Out:
# PassengerId                                     631
# Survived                                          1
# Pclass                                            1
# Name           Barkworth, Mr. Algernon Henry Wilson
# Sex                                            male
# Age                                            80.0
# SibSp                                             0
# Parch                                             0
# Ticket                                        27042
# Fare                                           30.0
# Cabin                                           A23
# Embarked                                          S
# FamilySize                                        1
# Name: 630, dtype: object

# %%
df[['Age','Fare']].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
#  12  FamilySize   891 non-null    int64
# dtypes: float64(2), int64(6), str(5)
# memory usage: 90.6 KB

# %%
# Use map to transform data(Encoding sex column)
df['SexNumeric'] = df['Sex'].map({'male': 0, 'female': 1})
df[['Sex', 'SexNumeric']].head()
# Out:
#       Sex  SexNumeric
# 0    male           0
# 1  female           1
# 2  female           1
# 3  female           1
# 4    male           0

# %%
df.sample(2)
# Out:
#      PassengerId  Survived  Pclass  \
# 426          427         1       2
# 815          816         0       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 426  Clarke, Mrs. Charles V (Ada Maria Winfield)  female  28.0      1      0
# 815                             Fry, Mr. Richard    male   NaN      0      0
#
#      Ticket  Fare Cabin Embarked  FamilySize  SexNumeric
# 426    2003  26.0   NaN        S           2           1
# 815  112058   0.0  B102        S           1           0

# %%
# Rename column
df.rename(columns={"Sex":"Gender","SibSp":"Siblings_spouse"},inplace=True)

# %%
df = df.rename(columns={"Gender":"Sex", "Siblings_spouse": "SibSp"})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  SexNumeric
# 0      0         A/5 21171   7.2500   NaN        S           2           0
# 1      0          PC 17599  71.2833   C85        C           2           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1           1
# ...

# %% [markdown]
# ## Sorting and Grouping

# %%
df.sort_values('Age')
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# Desc Sort by Age
df.sort_values('Age',ascending=False)[['Name','Age','Pclass']].head()
# Out:
#                                      Name   Age  Pclass
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0       1
# 851                   Svensson, Mr. Johan  74.0       3
# 493               Artagaveytia, Mr. Ramon  71.0       1
# 96              Goldschmidt, Mr. George B  71.0       1
# 116                  Connors, Mr. Patrick  70.5       3

# %%
df.sort_values('Fare',ascending=False)[['Name','Fare','Pclass']].head(10)
# Out:
#                                                 Name      Fare  Pclass
# 679               Cardeza, Mr. Thomas Drake Martinez  512.3292       1
# 258                                 Ward, Miss. Anna  512.3292       1
# 737                           Lesurer, Mr. Gustave J  512.3292       1
# 88                        Fortune, Miss. Mabel Helen  263.0000       1
# 438                                Fortune, Mr. Mark  263.0000       1
# 341                   Fortune, Miss. Alice Elizabeth  263.0000       1
# 27                    Fortune, Mr. Charles Alexander  263.0000       1
# 742            Ryerson, Miss. Susan Parker "Suzette"  262.3750       1
# 311                       Ryerson, Miss. Emily Borie  262.3750       1
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  247.5208       1

# %% [markdown]
# ## Bivariate Analysis: Relationship Between Features and Target Variable
#
# In this section, we look at how different categories—like a passenger's class or gender affected their chances of surviving. By grouping these features and calculating the average of the Survived column, we can see clear patterns in the data. So, Let's now analyze how individual features (`pclass`, `sex`, `age` etc) relate to the target variable (`Survived`) by computing the average survival rate across different categories.

# %%
df[['Pclass','Survived']].groupby('Pclass').mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df[["Pclass", "Survived"]].groupby('Pclass', as_index=False).mean().sort_values('Survived', ascending=False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df[['Sex','Survived']].groupby('Sex',as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
df[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
df[['Sex','Survived']].groupby('Sex',as_index=False).sum()
# Out:
#       Sex  Survived
# 0  female       233
# 1    male       109

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  FamilySize  SexNumeric
# 0      0         A/5 21171   7.2500   NaN        S           2           0
# 1      0          PC 17599  71.2833   C85        C           2           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           1           1
# ...

# %%
df.groupby("Pclass")["Fare"].mean().sort_values(ascending=False)
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %% [markdown]
# ## Plotting

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.boxplot(x='Sex', y='Age', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
# 📊 Visualization: Distribution of Age
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'].dropna(), kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
df[['Pclass','Sex']].groupby('Pclass').value_counts()
# Out:
# Pclass  Sex
# 1       male      122
#         female     94
# 2       male      108
#         female     76
# 3       male      347
#         female    144
# Name: count, dtype: int64

# %%
sns.countplot( x='Sex',hue='Pclass', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# ## Missing Values and Data Types

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FamilySize       0
# SexNumeric       0
# dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  FamilySize  SexNumeric
# 0      0         A/5 21171   7.2500        S           2           0
# 1      0          PC 17599  71.2833        C           2           1
# 2      0  STON/O2. 3101282   7.9250        S           1           1
# ...

# %%
df['Age'].skew() # if skew > 1 use median otherwise use mean
# Out:
# np.float64(0.38910778230082704)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# FamilySize     0
# SexNumeric     0
# dtype: int64

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Embarked           str
# FamilySize       int64
# SexNumeric       int64
# dtype: object

# %% [markdown]
# ## Numpy array & Vector

# %% [markdown]
# ## Note:
# ### 1 dimensional array - vector

# %%
a = np.array([1,2,2,4,6])  # vector -> mango
b = np.array([1,2,3,4,5]) # 1 dimensianal array - vector -> apple
c = np.array([3,7,8,4,9])

# %%
a.dot(b)
# Out:
# np.int64(57)

# %%
a.dot(c)
# Out:
# np.int64(103)
